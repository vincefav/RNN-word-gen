# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

import pandas as pd
# Out:
# C:\Users\Vince\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# The complete works of Shakespeare in a single text file!
# (Technology is amazing, isn't it?)
text = io.open('shakespeare.txt', encoding='utf-8').read().lower()

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))

# Allows us to convert characters to numbers, and vice-versa
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 58

# %%
# Put the text in semi-redundant sequences of maxlen characters
# (Best shown through example; see following cells)

maxlen = 14
step = 1

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 5447150

# %%
# Creating blank tensors that we'll fill in...
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)


# But we need to convert the character to an index because we're one-hot encoding
# So we use the char_indices dict
# y[i, (char_index)] is the cell we need to one-hot encode
for i, sentence in enumerate(sentences):
    for j, char in enumerate(sentence):
        x[i, j, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# Each data point in x is a one-hot-encoded sequence of length 40
print('x.shape:', x.shape)

# Each y is a one-hot-encoded next character
print('y.shape:', y.shape)
# Out:
# Vectorization...
# x.shape: (5447150, 14, 58)
# y.shape: (5447150, 58)

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce = ReduceLROnPlateau(factor=.01, patience=3, monitor='loss')
es = EarlyStopping(patience=5, monitor='loss')

# %%
# Build the model: a single LSTM
print('Building model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Building model...

# %%
try:
    model.fit(x, y,
              batch_size=256,
              epochs=1, callbacks=[es, reduce])
except KeyboardInterrupt:
    pass
# Out:
# Epoch 1/1
#  - ETA: 50s - loss: 1.3691

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# Construct a "seed sentence", from the random point, of maxlen length
start_index = random.randint(0, len(text) - maxlen - 1)

# Keep a string of all generated words
allgen = ''

for diversity in [0.2, 0.5, 1.0, 1.2]:

    generated = ''

    sentence = text[start_index: start_index + maxlen]
    generated += sentence

    # We're going to sequentially build on this empty string (400 times)
    sys.stdout.write(generated)

    for i in range(1000):

        # This one-hot encodes the sentence we currently have
        # (Starting with the seed sentence)
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        # Predict the one-hot encoding we just made
        preds = model.predict(x_pred, verbose=0)[0]

        # Sample an index (diversity tries different temperatures)
        next_index = sample(preds, diversity)

        # Convert that index number to a character
        next_char = indices_char[next_index]

        # Add that character to our sentence
        generated += next_char
        allgen += next_char

        # Shift the sentence string by 1 to include our new, predicted character
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# garet. nay, good man and the man the state of the compantion and the present to the month of the words of the prince to a soldier, and but the steel of the strange the song of the world.
#
# garet. nay, gone of them.
#     the man and another field me day the good speak
#     with word which she say up the master man harges for it.
#     i have the cass'd bear my sister was soul of him were the souls; and the true mondy of the shall the art thou see it thou thou hast not to the palicial precious, and are the duke and all the strong of his health,
#     to be the vile the true unknowledge them i am as sit to me.
#   troilus. why i do not be this same so comes the strife of his lovers will be sails and silvian of the field the good is a strack a fear the month the wars the compisted himself as so take them bearing of summer is to the wicked stephant of all the bear the great musician.
#     i have the warrance
#     and so away him.
#     it was her law,
#     and made themselves. had him of him,
#     to sure in this too but the rives of a man the parted her this that the month of these
#     stand's a crown as my wife is a satisfar, and curse him, and speeding of the man it hath hand be count since the duke
# garet. nay, go with him.
#   secaro.  the stand unere in change!
#   ourliff! as this time haw suit tenty yours.
#   king. the do recomsanttle con!
#   poster. it is love
#     though canst thou stands not'd cisanis sing seen
#     of uadon, astencill'd of,
#     new of dispiter of the refor me, question's of all;
#     and, a groop wo'll freshorf of a youth; if i charge thy chinders of eye wols-soft; and deceive, a turth mustage,
#      for their death'd,
#     devils your some depended great finds of shasur,
#     thunch.
#   clard. by flight-onvence'ly to dolel these hang, kind.
#   antony. i have stain her, for my daughter, letper. come trees.
#
# elemtrains. no, tell you, a cliuge.
#   king. you anothers' work;
#     'now a dung upon his do free long thinule, name till this horse in the pleasure, seein to no marths broke of him,
#     and wanter a my faulianis, and a number in the putefens,
#     a brother. whichs are to your day to like one,
#     my stavy a king of copies me
#     whose questions, and virginils to him.
#   ophia. o,
# garet. nay, go arro,
#   or bend atouy let allow magurs'd,
#     take not downlanges, is ladyers.
#   prove. i have boot; for have their other
#     with friend, amar;
#     betless youl! you have this po, at bones relies?
#   slumblook. go
# drowing ! he-locklancom! fulwships one's martrerlisous'
#     of brongeds these sun.
#
#   king. o i of your sistered- 'tis so fearch. buckinghism, desire to missets his master
#     but shy gide
#      go't. then i grow, were writes, first himself.
#     have they partur'd.
#   blos. when your; and by sense of others; that interrecies, youl-hola's daughter.
#     awaltgeing diri jewdle romection lead you, keep honororous is keep tongetby, dey
#     his o, alstrepain'd in her.
#   crown, peryon temptily.
#   lewis. hargden trircrothers time i chamb the vulties!
#   orlius. pedant nob,
#
#     are-
#   wilos. dog!
#    upon  his o't.
#   disforms. as thoughls now; the wet]
#  slearing. adg.ting change,
#     seen if ho, ansier, deptlemate unpist on.
#     poshion; price to by no. it they shus thought were

# %%
model.save_weights('shakespeare.h5')
